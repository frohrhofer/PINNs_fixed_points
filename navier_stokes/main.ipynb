# %% [markdown]
# ### Load and Modify Configuration File

# %%
from configs.config_loader import load_config
config = load_config('configs/default.yaml')
# Out:
# version : default
# seed : 1
# x_domain : [-5, 15]
# y_domain : [-10, 10]
# t_initial : [0, 3]
# t_domain : [0, 18]
# N_hidden : 8
# N_neurons : 100
# activation : tanh
# N_initial : 100000
# N_batch : 1024
# N_collocation : 256
# N_cylinder : 128
# N_inlet : 128
# N_outlet : 128
# N_wall : 256
# N_epochs : 1000
# learning_rate : 0.001
# decay_rate : 1.0
# freq_log : 1
# freq_print : 10
# keys_print : ['loss_train', 'loss_IC', 'loss_NS', 'loss_BC']

# %% [markdown]
# ### Initialize Physics-Informed Neural Network

# %%
from model.neural_net import PhysicsInformedNN
PINN = PhysicsInformedNN(config, verbose=True)
# Out:
# Model: "nested_PINN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               400
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 100)               10100
#
#  dense_6 (Dense)             (None, 100)               10100
#
#  dense_7 (Dense)             (None, 100)               10100
#
#  dense_8 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 71,302
# Trainable params: 71,302
# Non-trainable params: 0
# _________________________________________________________________
# *** DataLoader initialized ***
# *** PINN build & initialized ***

# %% [markdown]
# ### Train Physics-Informed Neural Network

# %%
training_log = PINN.train()
# Out:
# *** CFD data loaded ***
# Trainset size:  100000
# *** Training started... ***
#    0/1000 | loss_train: 9.66e-02 | loss_IC: 5.03e-02 | loss_NS: 6.26e-03 | loss_BC: 4.01e-02
#   10/1000 | loss_train: 2.54e-02 | loss_IC: 1.61e-02 | loss_NS: 1.46e-03 | loss_BC: 7.81e-03
#   20/1000 | loss_train: 9.97e-03 | loss_IC: 5.65e-03 | loss_NS: 1.22e-03 | loss_BC: 3.10e-03
#   30/1000 | loss_train: 5.90e-03 | loss_IC: 3.62e-03 | loss_NS: 5.02e-04 | loss_BC: 1.78e-03
#   40/1000 | loss_train: 7.11e-03 | loss_IC: 2.85e-03 | loss_NS: 1.98e-03 | loss_BC: 2.27e-03
#   50/1000 | loss_train: 4.13e-03 | loss_IC: 1.81e-03 | loss_NS: 7.44e-04 | loss_BC: 1.58e-03
#   60/1000 | loss_train: 3.67e-03 | loss_IC: 1.38e-03 | loss_NS: 1.82e-03 | loss_BC: 4.73e-04
#   70/1000 | loss_train: 4.50e-03 | loss_IC: 1.84e-03 | loss_NS: 1.65e-03 | loss_BC: 1.01e-03
#   80/1000 | loss_train: 1.34e-01 | loss_IC: 4.01e-02 | loss_NS: 3.29e-03 | loss_BC: 9.10e-02
#   90/1000 | loss_train: 5.66e-03 | loss_IC: 3.56e-03 | loss_NS: 9.57e-04 | loss_BC: 1.15e-03
#  100/1000 | loss_train: 3.26e-03 | loss_IC: 1.88e-03 | loss_NS: 5.90e-04 | loss_BC: 7.93e-04
#  110/1000 | loss_train: 8.05e-03 | loss_IC: 3.96e-03 | loss_NS: 1.12e-03 | loss_BC: 2.97e-03
#  120/1000 | loss_train: 6.50e-03 | loss_IC: 2.24e-03 | loss_NS: 1.79e-03 | loss_BC: 2.46e-03
#  130/1000 | loss_train: 8.27e-03 | loss_IC: 4.84e-03 | loss_NS: 1.44e-03 | loss_BC: 1.98e-03
#  140/1000 | loss_train: 5.44e-03 | loss_IC: 1.53e-03 | loss_NS: 3.12e-03 | loss_BC: 7.82e-04
#  150/1000 | loss_train: 5.58e-03 | loss_IC: 2.77e-03 | loss_NS: 9.08e-04 | loss_BC: 1.91e-03
#  160/1000 | loss_train: 2.12e-03 | loss_IC: 9.86e-04 | loss_NS: 6.16e-04 | loss_BC: 5.20e-04
#  170/1000 | loss_train: 6.71e-03 | loss_IC: 3.17e-03 | loss_NS: 9.15e-04 | loss_BC: 2.62e-03
#  180/1000 | loss_train: 2.01e-02 | loss_IC: 6.57e-03 | loss_NS: 7.02e-03 | loss_BC: 6.48e-03
#  190/1000 | loss_train: 2.46e-03 | loss_IC: 1.14e-03 | loss_NS: 8.10e-04 | loss_BC: 5.17e-04
#  200/1000 | loss_train: 1.44e-03 | loss_IC: 6.31e-04 | loss_NS: 4.33e-04 | loss_BC: 3.76e-04
#  210/1000 | loss_train: 2.71e-02 | loss_IC: 1.65e-02 | loss_NS: 5.70e-03 | loss_BC: 4.90e-03
#  220/1000 | loss_train: 6.85e-03 | loss_IC: 2.98e-03 | loss_NS: 2.95e-03 | loss_BC: 9.18e-04
#  230/1000 | loss_train: 1.65e-02 | loss_IC: 3.79e-03 | loss_NS: 1.11e-02 | loss_BC: 1.61e-03
#  240/1000 | loss_train: 5.23e-03 | loss_IC: 2.35e-03 | loss_NS: 1.62e-03 | loss_BC: 1.25e-03
#  250/1000 | loss_train: 4.47e-03 | loss_IC: 8.49e-04 | loss_NS: 3.22e-03 | loss_BC: 3.95e-04
#  260/1000 | loss_train: 3.74e-03 | loss_IC: 1.26e-03 | loss_NS: 9.42e-04 | loss_BC: 1.54e-03
#  270/1000 | loss_train: 5.23e-03 | loss_IC: 1.88e-03 | loss_NS: 1.71e-03 | loss_BC: 1.64e-03
#  280/1000 | loss_train: 3.41e-03 | loss_IC: 1.48e-03 | loss_NS: 1.22e-03 | loss_BC: 7.07e-04
#  290/1000 | loss_train: 2.65e-03 | loss_IC: 1.24e-03 | loss_NS: 5.46e-04 | loss_BC: 8.68e-04
#  300/1000 | loss_train: 9.86e-03 | loss_IC: 6.12e-03 | loss_NS: 1.48e-03 | loss_BC: 2.26e-03
#  310/1000 | loss_train: 5.79e-03 | loss_IC: 3.56e-03 | loss_NS: 1.35e-03 | loss_BC: 8.80e-04
#  320/1000 | loss_train: 2.65e-03 | loss_IC: 9.64e-04 | loss_NS: 9.24e-04 | loss_BC: 7.64e-04
#  330/1000 | loss_train: 4.67e-03 | loss_IC: 2.75e-03 | loss_NS: 8.01e-04 | loss_BC: 1.12e-03
#  340/1000 | loss_train: 4.07e-03 | loss_IC: 1.39e-03 | loss_NS: 1.80e-03 | loss_BC: 8.79e-04
#  350/1000 | loss_train: 3.74e-02 | loss_IC: 2.53e-02 | loss_NS: 5.90e-03 | loss_BC: 6.26e-03
#  360/1000 | loss_train: 9.56e-03 | loss_IC: 4.20e-03 | loss_NS: 3.91e-03 | loss_BC: 1.45e-03
#  370/1000 | loss_train: 3.62e-03 | loss_IC: 1.85e-03 | loss_NS: 1.07e-03 | loss_BC: 6.97e-04
#  380/1000 | loss_train: 3.76e-03 | loss_IC: 1.66e-03 | loss_NS: 1.31e-03 | loss_BC: 7.91e-04
#  390/1000 | loss_train: 1.74e-03 | loss_IC: 8.50e-04 | loss_NS: 5.36e-04 | loss_BC: 3.51e-04
#  400/1000 | loss_train: 4.12e-03 | loss_IC: 7.72e-04 | loss_NS: 2.93e-03 | loss_BC: 4.21e-04
#  410/1000 | loss_train: 1.66e-03 | loss_IC: 5.68e-04 | loss_NS: 7.24e-04 | loss_BC: 3.72e-04
#  420/1000 | loss_train: 2.65e-03 | loss_IC: 7.62e-04 | loss_NS: 7.98e-04 | loss_BC: 1.09e-03
#  430/1000 | loss_train: 2.28e-03 | loss_IC: 6.94e-04 | loss_NS: 1.24e-03 | loss_BC: 3.53e-04
#  440/1000 | loss_train: 2.15e-03 | loss_IC: 9.05e-04 | loss_NS: 4.06e-04 | loss_BC: 8.43e-04
#  450/1000 | loss_train: 6.13e-03 | loss_IC: 2.79e-03 | loss_NS: 1.53e-03 | loss_BC: 1.81e-03
#  460/1000 | loss_train: 3.10e-03 | loss_IC: 1.39e-03 | loss_NS: 7.21e-04 | loss_BC: 9.86e-04
#  470/1000 | loss_train: 1.87e-03 | loss_IC: 7.89e-04 | loss_NS: 6.53e-04 | loss_BC: 4.31e-04
#  480/1000 | loss_train: 3.26e-03 | loss_IC: 1.13e-03 | loss_NS: 1.64e-03 | loss_BC: 4.91e-04
#  490/1000 | loss_train: 1.98e-03 | loss_IC: 5.13e-04 | loss_NS: 1.17e-03 | loss_BC: 2.89e-04
#  500/1000 | loss_train: 1.19e-03 | loss_IC: 5.54e-04 | loss_NS: 4.39e-04 | loss_BC: 1.99e-04
#  510/1000 | loss_train: 7.05e-02 | loss_IC: 4.47e-03 | loss_NS: 1.54e-03 | loss_BC: 6.45e-02
#  520/1000 | loss_train: 4.40e-03 | loss_IC: 1.77e-03 | loss_NS: 1.45e-03 | loss_BC: 1.17e-03
#  530/1000 | loss_train: 2.14e-03 | loss_IC: 6.65e-04 | loss_NS: 4.07e-04 | loss_BC: 1.07e-03
#  540/1000 | loss_train: 2.17e-03 | loss_IC: 6.09e-04 | loss_NS: 5.21e-04 | loss_BC: 1.04e-03
#  550/1000 | loss_train: 1.02e-03 | loss_IC: 3.41e-04 | loss_NS: 4.52e-04 | loss_BC: 2.30e-04
#  560/1000 | loss_train: 3.27e-03 | loss_IC: 1.22e-03 | loss_NS: 1.20e-03 | loss_BC: 8.51e-04
#  570/1000 | loss_train: 9.98e-04 | loss_IC: 2.85e-04 | loss_NS: 4.21e-04 | loss_BC: 2.93e-04
#  580/1000 | loss_train: 1.15e-03 | loss_IC: 3.53e-04 | loss_NS: 4.02e-04 | loss_BC: 4.00e-04
#  590/1000 | loss_train: 3.06e-03 | loss_IC: 8.13e-04 | loss_NS: 1.34e-03 | loss_BC: 9.09e-04
#  600/1000 | loss_train: 1.46e-03 | loss_IC: 3.63e-04 | loss_NS: 6.62e-04 | loss_BC: 4.31e-04
#  610/1000 | loss_train: 1.48e-03 | loss_IC: 3.68e-04 | loss_NS: 7.43e-04 | loss_BC: 3.73e-04
#  620/1000 | loss_train: 1.20e-03 | loss_IC: 4.13e-04 | loss_NS: 4.79e-04 | loss_BC: 3.04e-04
#  630/1000 | loss_train: 4.33e-03 | loss_IC: 2.14e-03 | loss_NS: 1.17e-03 | loss_BC: 1.03e-03
#  640/1000 | loss_train: 1.86e-03 | loss_IC: 8.03e-04 | loss_NS: 6.75e-04 | loss_BC: 3.87e-04
#  650/1000 | loss_train: 1.70e-03 | loss_IC: 6.48e-04 | loss_NS: 7.29e-04 | loss_BC: 3.19e-04
#  660/1000 | loss_train: 2.99e-03 | loss_IC: 8.24e-04 | loss_NS: 7.87e-04 | loss_BC: 1.38e-03
#  670/1000 | loss_train: 1.90e-03 | loss_IC: 3.94e-04 | loss_NS: 9.57e-04 | loss_BC: 5.51e-04
#  680/1000 | loss_train: 2.15e-03 | loss_IC: 5.59e-04 | loss_NS: 8.98e-04 | loss_BC: 6.95e-04
#  690/1000 | loss_train: 9.84e-04 | loss_IC: 3.38e-04 | loss_NS: 3.52e-04 | loss_BC: 2.94e-04
#  700/1000 | loss_train: 8.65e-04 | loss_IC: 2.67e-04 | loss_NS: 4.27e-04 | loss_BC: 1.72e-04
#  710/1000 | loss_train: 3.29e-03 | loss_IC: 9.57e-04 | loss_NS: 4.91e-04 | loss_BC: 1.85e-03
#  720/1000 | loss_train: 2.64e-03 | loss_IC: 9.95e-04 | loss_NS: 1.11e-03 | loss_BC: 5.31e-04
#  730/1000 | loss_train: 9.43e-04 | loss_IC: 2.41e-04 | loss_NS: 5.33e-04 | loss_BC: 1.69e-04
#  740/1000 | loss_train: 1.37e-03 | loss_IC: 3.10e-04 | loss_NS: 7.89e-04 | loss_BC: 2.67e-04
#  750/1000 | loss_train: 1.05e-03 | loss_IC: 3.13e-04 | loss_NS: 3.46e-04 | loss_BC: 3.88e-04
#  760/1000 | loss_train: 6.63e-04 | loss_IC: 2.62e-04 | loss_NS: 2.10e-04 | loss_BC: 1.91e-04
#  770/1000 | loss_train: 3.49e-03 | loss_IC: 1.89e-03 | loss_NS: 6.48e-04 | loss_BC: 9.50e-04
#  780/1000 | loss_train: 1.28e-03 | loss_IC: 4.38e-04 | loss_NS: 4.82e-04 | loss_BC: 3.63e-04
#  790/1000 | loss_train: 1.01e-03 | loss_IC: 2.64e-04 | loss_NS: 4.04e-04 | loss_BC: 3.41e-04
#  800/1000 | loss_train: 9.88e-04 | loss_IC: 3.81e-04 | loss_NS: 2.99e-04 | loss_BC: 3.08e-04
#  810/1000 | loss_train: 9.40e-04 | loss_IC: 3.50e-04 | loss_NS: 3.27e-04 | loss_BC: 2.63e-04
#  820/1000 | loss_train: 2.96e-03 | loss_IC: 1.03e-03 | loss_NS: 8.61e-04 | loss_BC: 1.07e-03
#  830/1000 | loss_train: 2.68e-03 | loss_IC: 1.18e-03 | loss_NS: 8.22e-04 | loss_BC: 6.76e-04
#  840/1000 | loss_train: 1.27e-03 | loss_IC: 2.88e-04 | loss_NS: 4.24e-04 | loss_BC: 5.60e-04
#  850/1000 | loss_train: 7.98e-03 | loss_IC: 4.02e-03 | loss_NS: 1.64e-03 | loss_BC: 2.32e-03
#  860/1000 | loss_train: 1.29e-03 | loss_IC: 2.92e-04 | loss_NS: 3.78e-04 | loss_BC: 6.17e-04
#  870/1000 | loss_train: 1.32e-03 | loss_IC: 6.69e-04 | loss_NS: 3.81e-04 | loss_BC: 2.73e-04
#  880/1000 | loss_train: 9.44e-04 | loss_IC: 2.65e-04 | loss_NS: 3.64e-04 | loss_BC: 3.15e-04
#  890/1000 | loss_train: 1.53e-03 | loss_IC: 3.84e-04 | loss_NS: 4.13e-04 | loss_BC: 7.31e-04
#  900/1000 | loss_train: 3.02e-03 | loss_IC: 7.08e-04 | loss_NS: 9.72e-04 | loss_BC: 1.34e-03
#  910/1000 | loss_train: 1.36e-03 | loss_IC: 2.94e-04 | loss_NS: 6.87e-04 | loss_BC: 3.82e-04
#  920/1000 | loss_train: 9.13e-04 | loss_IC: 2.73e-04 | loss_NS: 3.95e-04 | loss_BC: 2.44e-04
#  930/1000 | loss_train: 8.29e-04 | loss_IC: 2.29e-04 | loss_NS: 2.17e-04 | loss_BC: 3.83e-04
#  940/1000 | loss_train: 3.74e-03 | loss_IC: 8.71e-04 | loss_NS: 6.26e-04 | loss_BC: 2.24e-03
#  950/1000 | loss_train: 7.40e-03 | loss_IC: 3.95e-03 | loss_NS: 8.60e-04 | loss_BC: 2.58e-03
#  960/1000 | loss_train: 8.84e-04 | loss_IC: 2.59e-04 | loss_NS: 3.12e-04 | loss_BC: 3.13e-04
#  970/1000 | loss_train: 1.50e-03 | loss_IC: 5.16e-04 | loss_NS: 4.46e-04 | loss_BC: 5.40e-04
#  980/1000 | loss_train: 9.13e-04 | loss_IC: 3.37e-04 | loss_NS: 3.77e-04 | loss_BC: 1.99e-04
#  990/1000 | loss_train: 1.06e-03 | loss_IC: 3.12e-04 | loss_NS: 4.76e-04 | loss_BC: 2.69e-04
# *** logs saved ***
# ### Training finished ###

# %% [markdown]
# # Plot Section

# %%
from model.plots import learning_curves, flow_field

# %% [markdown]
# ### Learning Curves

# %%
learning_curves(training_log)

# %% [markdown]
# ### Flow Field

# %%
flow_field(PINN, time=3)
# Out:
# *** CFD data loaded ***

# %%
flow_field(PINN, time=12)
# Out:
# *** CFD data loaded ***
